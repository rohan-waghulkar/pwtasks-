# %%
import pandas as p

# %% [markdown]
# ## Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# #### 1)p.DataFrames()
#  this function creates new dataframe(table like format of data.

# %%
data={'Name':['rohan','sahil'],'mail':['rohan@123','sahil@321']}

# %%
df=p.DataFrame(data)

# %%
df
# Out:
#     Name       mail
# 0  rohan  rohan@123
# 1  sahil  sahil@321

# %% [markdown]
# #### 2) .drop()  => Drop specified labels from rows or columns.

# %%
df.drop('mail',axis=1,inplace=True)

# %%
df
# Out:
#     Name
# 0  rohan
# 1  sahil

# %%
df1=p.read_csv("services.csv")

# %%
df1
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# #### 3) .set_index()

# %%
df1.set_index('audience').head()
# Out:
#                                                     id  location_id  \
# audience
# Older adults age 55 or over, ethnic minorities ...   1            1
# Residents of San Mateo County age 55 or over         2            2
# Older adults age 55 or over who can benefit fro...   3            3
# Parents, children, families with problems of cu...   4            4
# Low-income working families with children trans...   5            5
#
#                                                     program_id  \
# audience
# Older adults age 55 or over, ethnic minorities ...         NaN
# Residents of San Mateo County age 55 or over               NaN
# Older adults age 55 or over who can benefit fro...         NaN
# Parents, children, families with problems of cu...         NaN
# Low-income working families with children trans...         NaN
#
#                                                    accepted_payments  \
# audience
# Older adults age 55 or over, ethnic minorities ...               NaN
# ...

# %% [markdown]
# #### 4) .dropna()

# %%
df1.dropna(axis=1)
# Out:
#     id  location_id                                application_process  \
# 0    1            1                         Walk in or apply by phone.
# 1    2            2                 Apply by phone for an appointment.
# 2    3            3        Phone for information (403-4300 Ext. 4322).
# 3    4            4                                    Apply by phone.
# 4    5            5                             Phone for information.
# 5    6            6  Walk in or apply by phone for membership appli...
# 6    7            7  Apply by phone or be referred by a doctor, soc...
# 7    8            8                                    Apply by phone.
# 8    9            9  Walk in. Proof of residency in California requ...
# 9   10           10  Walk in. Proof of California residency to rece...
# 10  11           11  Walk in. Proof of California residency require...
# 11  12           12  Walk in or apply by phone, email or webpage re...
# ...

# %% [markdown]
# #### 5).groupby()

# %%
obj=df1.groupby('status')

# %%
obj.mean()
# Out:
# /tmp/ipykernel_70/1582909037.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   obj.mean()
#                  id  location_id  program_id
# status
# active    11.190476    11.142857         NaN
# defunct   20.000000    20.000000         NaN
# inactive  21.000000    21.000000         NaN

# %% [markdown]
# ## Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
data1={'a':['w','x','y','z'],'b':['a','b','c','d'],'c':['l','m','n','o']}

# %%
df=p.DataFrame(data1)

# %%
df
# Out:
#    a  b  c
# 0  w  a  l
# 1  x  b  m
# 2  y  c  n
# 3  z  d  o

# %%
def reind(df):
    new_index = range(1, 2 * len(df) + 1, 2)
    df.set_index(p.Index(new_index), inplace=True)
    return df

# %%
df=reind(df)

# %%
df
# Out:
#    a  b  c
# 1  w  a  l
# 3  x  b  m
# 5  y  c  n
# 7  z  d  o

# %%
len(df)
# Out:
# 4

# %% [markdown]
# ## Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console.
# #### For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.

# %%
d=[10,20,30,40,50]
df=p.DataFrame({"values":d})

# %%
def calculate(df):
    cunt=0
    for i in df['values'][0:3]:
        cunt+=i
    print(cunt)

# %%
calculate(df)
# Out:
# 60

# %% [markdown]
# ## Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column

# %%
text=['abc','def','ghi','jkl','mno']
df2=p.DataFrame({'Text':text})

# %%
def add_col(df):
    col_name=input("Enter column name")
    df[col_name]=df['Text'].apply(lambda x:len(x))
    return df

# %%
add_col(df2)
# Out:
# Enter column name Text length
#   Text  Text length
# 0  abc            3
# 1  def            3
# 2  ghi            3
# 3  jkl            3
# 4  mno            3

# %% [markdown]
# ## Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# DataFrame.size(): This method returns the total number of elements in the DataFrame.i.e it returns the product of the number of rows and columns in the DataFrame.
#
# DataFrame.shape(): This method returns a tuple of two values: The number of rows is given by the first element of the tuple and the number of columns by the second element.

# %% [markdown]
# ## Q6. Which function of pandas do we use to read an excel file?

# %% [markdown]
# To read an exel file we use read_exel() method . example df=pandas.read_exel('filename.xlsx')

# %% [markdown]
# ## Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.
# ## The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %%
df=p.DataFrame({'Email':['john@example.com','sarah@company.net','david@school.edu','lisa@blog.org','mike@consulting.co.uk']})

# %%
df
# Out:
#                    Email
# 0       john@example.com
# 1      sarah@company.net
# 2       david@school.edu
# 3          lisa@blog.org
# 4  mike@consulting.co.uk

# %%
def get_username(df):
    df['Username']=df['Email'].apply(lambda x:x.split('@')[0])
    return df

# %%
get_username(df)
# Out:
#                    Email Username
# 0       john@example.com     john
# 1      sarah@company.net    sarah
# 2       david@school.edu    david
# 3          lisa@blog.org     lisa
# 4  mike@consulting.co.uk     mike

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
# For example, if df contains the following values:
#
# A B C
#
# 0 3 5 1
#
# 1 8 2 7
#
# 2 6 9 4
#
# 3 2 3 5
#
# 4 9 1 2
#
# Your function should select the following rows: A B C
#
# 1 8 2 7
#
# 4 9 1 2
#
# The function should return a new DataFrame that contains only the selected rows.

# %%
df=p.DataFrame({'a':[3,8,6,2,9],'b':[5,2,9,3,1],'c':[1,7,4,5,2]})

# %%
df
# Out:
#    a  b  c
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def select(df):
    val=(df['a']>5)&(df['c']<10)
    new_df=df[val]
    return new_df

# %%
new=select(df)

# %% [markdown]
# new

# %% [markdown]
# ## Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %%
def calculations(df):
    print('mean : ',df['values'].mean())
    print('median : ',df['values'].median())
    print('Standard daviation : ',df['values'].std())

# %%
df=p.DataFrame({'values':[1,2,3,4,5,6,7]})

# %%
calculations(df)
# Out:
# mean :  4.0
# median :  4.0
# Standard daviation :  2.160246899469287

# %% [markdown]
# ## Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
def add_moving_average(df):
    df.set_index('Date', inplace=True)
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()
    df.reset_index(inplace=True)

    return df

# %% [markdown]
# ## Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
#
# 0 2023-01-01
#
# 1 2023-01-02
#
# 2 2023-01-03
#
# 3 2023-01-04
#
# 4 2023-01-05
#
# Your function should create the following DataFrame:
#
# Date Weekday
#
# 0 2023-01-01 Sunday
#
# 1 2023-01-02 Monday
#
# 2 2023-01-03 Tuesday
#
# 3 2023-01-04 Wednesday
#
# 4 2023-01-05 Thursday
#
# The function should return the modified DataFrame.

# %%
def getdays(df):
    df['Date']=p.to_datetime(df['Date'])
    df['Weekday']=df['Date'].dt.day_name()
    return df

# %%
df4=p.DataFrame({'Date':['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05']})

# %%
getdays(df4)
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# ## Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
def select_date_range(df):
    df['Date'] = p.to_datetime(df['Date'])
    mask = (df['Date'] >= '2023-01-01') & (df['Date'] <= '2023-01-31')
    selected_df = df.loc[mask]
    return selected_df

# %%
print(select_date_range(df4))
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# ## Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# ## The mostimportant library that we have to import is " pandas"
